# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
from septr import SeparableTr 
# Cargar un archivo de audio
y, sr = librosa.load('03-01-07-02-02-02-01.wav', sr=None)
# Extraer MFCCs
mfccs = librosa.feature.mfcc(y=y, sr=sr)

# %%
D = librosa.amplitude_to_db(np.abs(librosa.stft(y)), ref=np.max)

# Visualizar el espectrograma
plt.figure(figsize=(10, 4))
librosa.display.specshow(D, sr=sr, x_axis='time', y_axis='log')
plt.colorbar(format='%+2.0f dB')
plt.title('Espectrograma')
plt.show()
# Out:
# /datassd/home/spastor/.conda/envs/septrenv/lib/python3.7/site-packages/librosa/display.py:1372: MatplotlibDeprecationWarning: SymmetricalLogScale got an unexpected keyword argument 'base'. In the future this will raise TypeError
#   scaler(mode, **kwargs)
